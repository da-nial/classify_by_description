# %%
# %cd /home/danialz/Projects/classify_by_description_release
# !ls
# Out:
# /home/danialz/Projects/classify_by_description_release
# attributes.txt		   imagenet_classes.txt
# cam.py			   imagenet_classes.txt.1
# cam_sims_average.csv	   label_encodings.pth
# cat.jpg			   loading_helpers.py
# cat_pillow_circled.jpg	   load.py
# classbydesc.yml		   main.py
# class_counters.csv	   notebooks
# data			   old_main.py
# datasets.py		   __pycache__
# description_encodings.pth  pytorch_grad_cam
# descriptors		   pytorch_grad_cam_wrapper.py
# descriptor_strings.py	   README.md
# evaluate.py		   res.csv
# evaluate_with_gradcam.py   res_per_cls.csv
# evaluate_with_scorecam.py  run_17611
# figs			   scratch_grad_cam
# generate_descriptors.py    utils.py

# %%
import importlib
import main
importlib.reload(main)
# Out:
# /home/danialz/anaconda3/envs/minvis/lib/python3.8/site-packages/scipy/__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "
# <module 'main' from '/home/danialz/Projects/classify_by_description_release/main.py'>

# %%
custom_hparams = {
    'dataset': 'cub',
    'model_size': 'RN50',
    'batch_size': 1,
    'cam_version': 'scorecam',
    'eval': 'with_scorecam',
}
cub_resnet_res = main.main(custom_hparams)
# Out:
# {'model_size': 'RN50', 'dataset': 'cub', 'batch_size': 1, 'device': 'cuda', 'category_name_inclusion': 'prepend', 'apply_descriptor_modification': True, 'verbose': False, 'image_size': 224, 'before_text': '', 'label_before_text': '', 'between_text': ', ', 'after_text': '', 'label_after_text': '', 'unmodify': True, 'seed': 1, 'cam_version': 'scorecam', 'eval': 'with_scorecam', 'data_dir': PosixPath('data/cub'), 'descriptor_fname': './descriptors/descriptors_cub'}
# Creating descriptors...
#
# Example description for class Black-footed Albatross: "Black-footed Albatross, which is a seabird"
#
# [('Black-footed Albatross', 0), ('Laysan Albatross', 1), ('Sooty Albatross', 2), ('Groove-billed Ani', 3), ('Crested Auklet', 4), ('Least Auklet', 5), ('Parakeet Auklet', 6), ('Rhinoceros Auklet', 7), ('Brewer Blackbird', 8), ('Red-winged Blackbird', 9)]
# Loading model...
# Encoding descriptions...
# Encoding labels...
# Evaluating...
# Warning: You are using ScoreCAM with target layers, however ScoreCAM will ignore them.
# 0it [00:00, ?it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# class: Black-footed Albatross
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# class: Laysan Albatross
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# class: Sooty Albatross
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# class: Groove-billed Ani
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# class: Crested Auklet
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# class: Least Auklet
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# class: Parakeet Auklet
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# class: Rhinoceros Auklet
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# class: Brewer Blackbird
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# class: Red-winged Blackbird
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# class: Rusty Blackbird
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# class: Yellow-headed Blackbird
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# class: Bobolink
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# class: Indigo Bunting
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# class: Lazuli Bunting
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# class: Painted Bunting
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# class: Cardinal
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# class: Spotted Catbird
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# class: Gray Catbird
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# class: Yellow-breasted Chat
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# class: Eastern Towhee
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# class: Chuck-will Widow
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# class: Brandt Cormorant
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# class: Red-faced Cormorant
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# class: Pelagic Cormorant
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# class: Bronzed Cowbird
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# class: Shiny Cowbird
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# class: Brown Creeper
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# class: American Crow
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# class: Fish Crow
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# class: Black-billed Cuckoo
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# class: Mangrove Cuckoo
# 0it [01:16, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 8
#       1 custom_hparams = {
#       2     'dataset': 'cub',
#       3     'model_size': 'RN50',
#    (...)
#       6     'eval': 'with_scorecam',
#       7 }
# ----> 8 cub_resnet_res = main.main(custom_hparams)
#
# File ~/Projects/classify_by_description_release/main.py:54, in main(custom_hparams)
#      50     return evaluate_with_gradcam(
#      51         model, dataloader, label_encodings, description_encodings, device
#      52     )
#      53 elif hparams['eval'] == 'with_scorecam':
# ---> 54     return evaluate_with_scorecam(
#      55         model, dataloader, label_encodings, description_encodings, device, hparams, class_labels
#      56     )
#
# File ~/Projects/classify_by_description_release/evaluate_with_scorecam.py:71, in evaluate(model, dataloader, label_encodings, description_encodings, device, hparams, class_labels)
#      69 img_np = reverse_transform(images[0])
#      70 for class_label in class_labels:
# ---> 71     cam = cam_wrapper(
#      72         inputs=(images, class_label),  # TODO fix this
#      73         label=None,
#      74         heatmap_size=image_size,
#      75         is_tokenized=False
#      76     )
#      77     # img_np = img.detach().cpu().numpy()
#      78     print(f'class: {class_label}')
#
# File ~/Projects/classify_by_description_release/pytorch_grad_cam_wrapper.py:216, in CAMWrapper.__call__(self, inputs, label, heatmap_size, is_tokenized)
#     212 if hasattr(self, "channel_dict"):
#     213     # self.cam.channels = self.channel_dict[text]
#     214     self.cam.channels = self._select_channels(text)
# --> 216 return self.getCAM(img, text_token, heatmap_size, label)
#
# File ~/Projects/classify_by_description_release/pytorch_grad_cam_wrapper.py:189, in CAMWrapper.getCAM(self, input_img, input_text, cam_size, target_category)
#     185     grayscale_cam = self.cam(inputs=cam_input, targets=target_category, image_size=cam_size)
#     186 # elif self.version == 'lime':
#     187 #     grayscale_cam = self.cam(inputs=cam_input, target=target_category, image_size=(224, 224), image=kwargs['image'])
#     188 else:
# --> 189     grayscale_cam = self.cam(input_tensor=cam_input, targets=target_category)
#     190     grayscale_cam = grayscale_cam[0, :]
#     192 return grayscale_cam
#
# File ~/Projects/classify_by_description_release/pytorch_grad_cam/base_cam.py:271, in BaseCAM.__call__(self, input_tensor, targets, aug_smooth, eigen_smooth)
#     267 if aug_smooth is True:
#     268     return self.forward_augmentation_smoothing(
#     269         input_tensor, targets, eigen_smooth)
# --> 271 return self.forward(input_tensor,
#     272                     targets, eigen_smooth)
#
# File ~/Projects/classify_by_description_release/pytorch_grad_cam/base_cam.py:162, in BaseCAM.forward(self, input_tensor, targets, eigen_smooth)
#     151     loss.backward(retain_graph=True)
#     153 # In most of the saliency attribution papers, the saliency is
#     154 # computed with a single target layer.
#     155 # Commonly it is the last convolutional layer.
#    (...)
#     160 # use all conv layers for example, all Batchnorm layers,
#     161 # or something else.
# --> 162 cam_per_layer = self.compute_cam_per_layer(input_tensor, targets, eigen_smooth)
#     163 return self.aggregate_multi_layers(cam_per_layer)
#
# File ~/Projects/classify_by_description_release/pytorch_grad_cam/base_cam.py:205, in BaseCAM.compute_cam_per_layer(self, input_tensor, targets, eigen_smooth)
#     202 if i < len(grads_list):
#     203     layer_grads = grads_list[i]
# --> 205 cam = self.get_cam_image(input_tensor,
#     206                          target_layer,
#     207                          targets,
#     208                          layer_activations,
#     209                          layer_grads,
#     210                          eigen_smooth)
#     211 cam = np.maximum(cam,
#     212                  0)  # * The difference between having this line is small, i.e., in COCO val, with this line is 20.83% and without this line is 20.86%
#     213 # normalize and resize cam
#
# File ~/Projects/classify_by_description_release/pytorch_grad_cam/base_cam.py:98, in BaseCAM.get_cam_image(self, input_tensor, target_layer, targets, activations, grads, eigen_smooth)
#      89 def get_cam_image(self,
#      90                   input_tensor: torch.Tensor,
#      91                   target_layer: torch.nn.Module,
#    (...)
#      95                   grads: torch.Tensor,
#      96                   eigen_smooth: bool = False) -> np.ndarray:
# ---> 98     self.weights = self.get_cam_weights(input_tensor,
#      99                                         target_layer,
#     100                                         targets,
#     101                                         activations,
#     102                                         grads)  # usually (n, c), but with einsum, now is support any shapes that match the corresponding dimension of activation. i.e., (c, w, h)
#     103     # weighted_activations = weights[:, :, None, None] * activations
#     104     weight_dim = self.dim_mapper(activations.shape, self.weights.shape)
#
# File ~/Projects/classify_by_description_release/pytorch_grad_cam/score_cam.py:58, in ScoreCAM.get_cam_weights(self, input_tensor, target_layer, targets, activations, grads)
#      54 activation_tensor = torch.from_numpy(activations)
#      55 # if self.cuda:
#      56 #     activation_tensor = activation_tensor.cuda()
# ---> 58 upsampled = upsample(activation_tensor.float())
#      60 maxs = upsampled.view(upsampled.size(0),
#      61                         upsampled.size(1), -1).max(dim=-1)[0]
#      62 mins = upsampled.view(upsampled.size(0),
#      63                         upsampled.size(1), -1).min(dim=-1)[0]
#
# File ~/anaconda3/envs/minvis/lib/python3.8/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/minvis/lib/python3.8/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/anaconda3/envs/minvis/lib/python3.8/site-packages/torch/nn/modules/upsampling.py:156, in Upsample.forward(self, input)
#     155 def forward(self, input: Tensor) -> Tensor:
# --> 156     return F.interpolate(input, self.size, self.scale_factor, self.mode, self.align_corners,
#     157                          recompute_scale_factor=self.recompute_scale_factor)
#
# File ~/anaconda3/envs/minvis/lib/python3.8/site-packages/torch/nn/functional.py:4020, in interpolate(input, size, scale_factor, mode, align_corners, recompute_scale_factor, antialias)
#    4014         if torch.are_deterministic_algorithms_enabled() and input.is_cuda:
#    4015             # Use slow decomp whose backward will be in terms of index_put
#    4016             # importlib is required because the import cannot be top level
#    4017             # (cycle) and cannot be nested (TS doesn't support)
#    4018             return importlib.import_module('torch._decomp.decompositions').upsample_bilinear2d_vec(
#    4019                 input, output_size, align_corners, scale_factors)
# -> 4020     return torch._C._nn.upsample_bilinear2d(input, output_size, align_corners, scale_factors)
#    4021 if input.dim() == 5 and mode == "trilinear":
#    4022     assert align_corners is not None
#
# KeyboardInterrupt:
